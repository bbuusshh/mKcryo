# %%
import yaml
with open("data_path.yaml", 'r') as stream:
    try:
        data_folder = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)
data_folder = data_folder["Vlad"]["office"]

# %%
figs_folder = r"C:\Data\Tin\density_figs"

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import matplotlib.ticker as ticker

# %%
img = mpimg.imread(f'{figs_folder}\\xy-scan_200p_10um - Copy.png')

# %%
plt.figure(figsize=(20, 20))
imgplot = plt.imshow(img, extent=[0, 10, 0, 10])
# plt.grid(color='black', linewidth = 2)
plt.savefig(f"{figs_folder}//10um.png")
